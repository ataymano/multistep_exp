# %%
from coba.learners import RandomLearner, EpsilonLearner, VowpalLearner, UcbTunedLearner
from coba.benchmarks import Benchmark

benchmark = Benchmark.from_file(r'C:\src\VowpalWabbit\coba\examples\benchmark_short.json')

learners = [
    RandomLearner(seed=10),
    EpsilonLearner(epsilon=0.025, seed=10),
    UcbTunedLearner(seed=10),
    VowpalLearner(bag=5, seed=10),
]

benchmark.evaluate(learners, 'bakeoff.log').standard_plot()
# Out:
# 2020-11-25 13:47:17 loading simulation...
# 2020-11-25 13:47:17   * loading openml 3...
# 2020-11-25 13:47:17     > loading descr from http...
# 2020-11-25 13:47:20       - finished after 2.64 seconds
# 2020-11-25 13:47:20     > loading tasks from http...
# 2020-11-25 13:47:24       - finished after 3.67 seconds
# 2020-11-25 13:47:24     > loading types from http...
# 2020-11-25 13:47:29       - finished after 5.38 seconds
# 2020-11-25 13:47:29     > loading data from http...
# 2020-11-25 13:47:31       - finished after 1.64 seconds
# 2020-11-25 13:47:31     > encoding data...
# 2020-11-25 13:47:31       - exception after 0.06 seconds:
#
#   File "C:\Users\ataymano\Anaconda3\lib\site-packages\coba\execution.py", line 263, in _with
#     yield self
#   File "C:\Users\ataymano\Anaconda3\lib\site-packages\coba\simulations.py", line 416, in from_csv
#     return ClassificationSimulation.from_table(csv_rows, label_col, has_header, default_meta, defined_meta)
#   File "C:\Users\ataymano\Anaconda3\lib\site-packages\coba\simulations.py", line 494, in from_table
#     encoding.append(encoder.encode(col))
#   File "C:\Users\ataymano\Anaconda3\lib\site-packages\coba\preprocessing.py", line 386, in encode
#     raise Exception(f"We were unable to find {e} in {self._levels.keys()}") from None
#
#   Exception: We were unable to find "'f'" in dict_keys(['f', 't'])
#
# 2020-11-25 13:47:31 loading simulation...
# 2020-11-25 13:47:31   * loading openml 6...
# 2020-11-25 13:47:31     > loading descr from http...
# 2020-11-25 13:47:33       - finished after 2.22 seconds
# 2020-11-25 13:47:33     > loading tasks from http...
# 2020-11-25 13:47:42       - finished after 8.44 seconds
# 2020-11-25 13:47:42     > loading types from http...
# 2020-11-25 13:47:47       - finished after 5.06 seconds
# 2020-11-25 13:47:47     > loading data from http...
# 2020-11-25 13:47:48       - finished after 1.73 seconds
# 2020-11-25 13:47:49     > encoding data...
# 2020-11-25 13:47:51       - finished after 2.67 seconds
# 2020-11-25 13:47:51     > finished after 20.49 seconds
# 2020-11-25 13:47:51   * finished after 20.49 seconds
# 2020-11-25 13:53:57 loading simulation...
# 2020-11-25 13:53:57   * loading openml 8...
# 2020-11-25 13:53:57     > loading descr from http...
# 2020-11-25 13:53:58       - finished after 0.49 seconds
# 2020-11-25 13:53:58     > loading tasks from http...
# 2020-11-25 13:53:59       - finished after 1.17 seconds
# 2020-11-25 13:53:59     > loading types from http...
# 2020-11-25 13:54:04       - finished after 5.15 seconds
# 2020-11-25 13:54:04     > loading data from http...
# 2020-11-25 13:54:05       - finished after 0.6 seconds
# 2020-11-25 13:54:05     > encoding data...
# 2020-11-25 13:54:05       - finished after 0.01 seconds
# 2020-11-25 13:54:05     > finished after 7.42 seconds
# 2020-11-25 13:54:05   * finished after 7.42 seconds
